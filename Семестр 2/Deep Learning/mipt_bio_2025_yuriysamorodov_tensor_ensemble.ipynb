# %% [markdown]
# <a href="https://colab.research.google.com/github/YuriySamorodov/MIPT/blob/main/%D0%A1%D0%B5%D0%BC%D0%B5%D1%81%D1%82%D1%80%202/Deep%20Learning/mipt_bio_2025_yuriysamorodov_tensor_ensemble.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Импортируем библиотеки
import tensorflow as tf
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, BatchNormalization, Dropout, GlobalAveragePooling2D, Input, Add, AveragePooling2D
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.optimizers import Adam, SGD, RMSprop
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, LearningRateScheduler
from tensorflow.keras.regularizers import l2
from sklearn.model_selection import train_test_split, StratifiedKFold
import pandas as pd
import numpy as np
import math
from sklearn.metrics import accuracy_score

# %%
# Проверяем GPU
print("GPU device:", tf.test.gpu_device_name())
# Out:
# GPU device: /device:GPU:0

# %%
# Загружаем датасеты
df_train = pd.read_csv('fmnist_train.csv')
df_test = pd.read_csv('fmnist_test.csv')

# Удаляем пустые значение
df_train.dropna(inplace=True)

# Подготовка фичей и заголовков
X_train_raw = df_train.drop(['label', 'Id'], axis=1).values
y_train_raw = df_train['label'].values
X_test_raw = df_test.drop('Id', axis=1).values
ids_test = df_test['Id']

# Нормализация изображений
X_train = X_train_raw.reshape(-1, 28, 28, 1).astype('float32') / 255.0
X_test = X_test_raw.reshape(-1, 28, 28, 1).astype('float32') / 255.0

# Преобразование меток
y_train = to_categorical(y_train_raw, num_classes=10)

print(f"Training samples: {X_train.shape[0]}")
print(f"Test samples: {X_test.shape[0]}")
# Out:
# Training samples: 17039
# Test samples: 10000

# %%
# Модель 1: Глубокая сверточная сеть с ResNet-связями
def create_model_1():
    model = Sequential()
    model.add(Input(shape=(28, 28, 1)))
    model.add(Conv2D(32, (3,3), activation='relu', padding='same'))
    model.add(BatchNormalization())
    model.add(Conv2D(32, (3,3), activation='relu', padding='same'))
    model.add(BatchNormalization())
    model.add(MaxPooling2D(2,2))
    model.add(Dropout(0.25))

    model.add(Conv2D(64, (3,3), activation='relu', padding='same'))
    model.add(BatchNormalization())
    model.add(Conv2D(64, (3,3), activation='relu', padding='same'))
    model.add(BatchNormalization())
    model.add(MaxPooling2D(2,2))
    model.add(Dropout(0.25))

    model.add(Conv2D(128, (3,3), activation='relu', padding='same'))
    model.add(BatchNormalization())
    model.add(Conv2D(128, (3,3), activation='relu', padding='same'))
    model.add(BatchNormalization())
    model.add(GlobalAveragePooling2D())

    model.add(Dense(512, activation='relu', kernel_regularizer=l2(0.001)))
    model.add(BatchNormalization())
    model.add(Dropout(0.5))
    model.add(Dense(256, activation='relu', kernel_regularizer=l2(0.001)))
    model.add(Dropout(0.3))
    model.add(Dense(10, activation='softmax'))
    return model

# %%
# Модель 2: Широкая сверточная сеть с широкими связями
def create_model_2():
    model = Sequential()
    model.add(Input(shape=(28, 28, 1)))
    model.add(Conv2D(64, (5,5), activation='relu', padding='same'))
    model.add(BatchNormalization())
    model.add(Conv2D(64, (3,3), activation='relu', padding='same'))
    model.add(BatchNormalization())
    model.add(MaxPooling2D(2,2))
    model.add(Dropout(0.3))

    model.add(Conv2D(128, (3,3), activation='relu', padding='same'))
    model.add(BatchNormalization())
    model.add(Conv2D(128, (3,3), activation='relu', padding='same'))
    model.add(BatchNormalization())
    model.add(AveragePooling2D(2,2))
    model.add(Dropout(0.3))

    model.add(Conv2D(256, (3,3), activation='relu', padding='same'))
    model.add(BatchNormalization())
    model.add(GlobalAveragePooling2D())

    model.add(Dense(1024, activation='relu', kernel_regularizer=l2(0.01)))
    model.add(BatchNormalization())
    model.add(Dropout(0.6))
    model.add(Dense(512, activation='relu', kernel_regularizer=l2(0.01)))
    model.add(Dropout(0.4))
    model.add(Dense(10, activation='softmax'))
    return model

# %%
# Модель 3: ResNet модель с пропусками
def create_model_3():
    input_layer = Input(shape=(28, 28, 1))

    # Первый  блок
    x = Conv2D(32, (3,3), activation='relu', padding='same')(input_layer)
    x = BatchNormalization()(x)
    x = Conv2D(32, (3,3), activation='relu', padding='same')(x)
    x = BatchNormalization()(x)
    x = MaxPooling2D(2,2)(x)
    x = Dropout(0.25)(x)

    # Второй блок с пропуском
    shortcut = Conv2D(64, (1,1), padding='same')(x)
    x = Conv2D(64, (3,3), activation='relu', padding='same')(x)
    x = BatchNormalization()(x)
    x = Conv2D(64, (3,3), activation='relu', padding='same')(x)
    x = BatchNormalization()(x)
    x = Add()([x, shortcut])
    x = MaxPooling2D(2,2)(x)
    x = Dropout(0.25)(x)

    # Третий блок
    x = Conv2D(128, (3,3), activation='relu', padding='same')(x)
    x = BatchNormalization()(x)
    x = GlobalAveragePooling2D()(x)

    x = Dense(256, activation='relu', kernel_regularizer=l2(0.001))(x)
    x = BatchNormalization()(x)
    x = Dropout(0.5)(x)
    output = Dense(10, activation='softmax')(x)

    model = Model(inputs=input_layer, outputs=output)
    return model

# %%
# Модель 4: Компактная модель
def create_model_4():
    model = Sequential()
    model.add(Input(shape=(28, 28, 1)))
    model.add(Conv2D(48, (3,3), activation='relu', padding='same'))
    model.add(BatchNormalization())
    model.add(Conv2D(48, (3,3), activation='relu', padding='same'))
    model.add(BatchNormalization())
    model.add(Dropout(0.2))

    model.add(Conv2D(96, (3,3), activation='relu', padding='same'))
    model.add(BatchNormalization())
    model.add(MaxPooling2D(2,2))
    model.add(Conv2D(96, (3,3), activation='relu', padding='same'))
    model.add(BatchNormalization())
    model.add(Dropout(0.3))

    model.add(Conv2D(192, (3,3), activation='relu', padding='same'))
    model.add(BatchNormalization())
    model.add(MaxPooling2D(2,2))
    model.add(Conv2D(192, (3,3), activation='relu', padding='same'))
    model.add(BatchNormalization())
    model.add(Dropout(0.4))

    model.add(GlobalAveragePooling2D())
    model.add(Dense(384, activation='relu', kernel_regularizer=l2(0.001)))
    model.add(BatchNormalization())
    model.add(Dropout(0.5))
    model.add(Dense(10, activation='softmax'))
    return model

# %%
# Повышаем разнообразие с использованием разных стратегий аугментации

def get_augmentation_generator(strategy='standard'):
    if strategy == 'standard':
        return ImageDataGenerator(
            rotation_range=15,
            width_shift_range=0.1,
            height_shift_range=0.1,
            shear_range=0.1,
            zoom_range=0.1,
            horizontal_flip=True,
            fill_mode='nearest'
        )
    elif strategy == 'aggressive':
        return ImageDataGenerator(
            rotation_range=25,
            width_shift_range=0.15,
            height_shift_range=0.15,
            shear_range=0.15,
            zoom_range=0.15,
            horizontal_flip=True,
            fill_mode='nearest'
        )
    elif strategy == 'minimal':
        return ImageDataGenerator(
            rotation_range=10,
            width_shift_range=0.08,
            height_shift_range=0.08,
            horizontal_flip=True
        )

# %%
# Тренируем модели
def train_model(model_func, model_name, X_train, y_train, X_val, y_val,
                optimizer_type='adam', augmentation='standard'):
    print(f"\n{'='*50}")
    print(f"Training {model_name}")
    print(f"{'='*50}")

    # Очищаем память
    tf.keras.backend.clear_session()

    model = model_func()

    # Применяем разные оптимизации для разных стратегий
    if optimizer_type == 'adam':
        optimizer = Adam(learning_rate=0.001)
    elif optimizer_type == 'sgd':
        optimizer = SGD(learning_rate=0.01, momentum=0.9, nesterov=True)
    elif optimizer_type == 'rmsprop':
        optimizer = RMSprop(learning_rate=0.001)

    model.compile(
        optimizer=optimizer,
        loss='categorical_crossentropy',
        metrics=['accuracy']
    )

    print(f"Model parameters: {model.count_params():,}")

    # Расширяем (аугментируем) данные
    datagen = get_augmentation_generator(augmentation)
    datagen.fit(X_train)

    # Callbacks
    early_stopping = EarlyStopping(
        monitor='val_accuracy',        # Следить за метрикой точности на валидации
        patience=15,                  # Остановить обучение, если улучшений не будет в течение 15 эпох
        restore_best_weights=True,    # Восстановить веса модели с лучшей эпохи после остановки
        mode='max',                   # Ожидается максимизация метрики (чем больше, тем лучше)
        verbose=1                    # Выводить подробную информацию о процессе остановки
    )


    reduce_lr = ReduceLROnPlateau(
        monitor='val_accuracy',
        factor=0.3,
        patience=5,
        verbose=1,
        mode='max',
        min_lr=1e-7
    )

    # Применяем оптимизаци для Nvidia Р100
    batch_size = 128  # Larger batch size for P100 GPU
    steps_per_epoch = len(X_train) // batch_size

    # Тренировка
    history = model.fit(
        datagen.flow(X_train, y_train, batch_size=batch_size),
        steps_per_epoch=steps_per_epoch,
        epochs=100,  # Increased epochs
        validation_data=(X_val, y_val),
        callbacks=[early_stopping, reduce_lr],
        verbose=1
    )

    # Оценка
    val_loss, val_acc = model.evaluate(X_val, y_val, verbose=0)
    print(f"{model_name} - Validation Accuracy: {val_acc:.4f} ({val_acc*100:.2f}%)")
    print(f"Best epoch: {len(history.history['val_accuracy']) - early_stopping.patience}")

    return model, history, val_acc

# %%
# Тренируем и проверяем ансамбль моделей
def train_ensemble_cv(n_splits=5):
    models = []
    val_accuracies = []

    # Конфиги моделей
    model_configs = [
        (create_model_1, "Deep CNN", 'adam', 'standard'),
        (create_model_2, "Wide CNN", 'rmsprop', 'aggressive'),
        (create_model_3, "ResNet-inspired", 'adam', 'minimal'),
        (create_model_4, "Compact Deep", 'sgd', 'standard')
    ]

    # Разбивка данных для тренировки ансамбля
    X_train_ens, X_val_ens, y_train_ens, y_val_ens = train_test_split(
        X_train, y_train, test_size=0.15, random_state=42, stratify=y_train_raw
    )

    print(f"Ensemble training set: {X_train_ens.shape[0]} семплов")
    print(f"Ensemble validation set: {X_val_ens.shape[0]} семплов")

    # Тренируем каждую мрдель
    for model_func, model_name, optimizer, augmentation in model_configs:
        model, history, val_acc = train_model(
            model_func, model_name, X_train_ens, y_train_ens,
            X_val_ens, y_val_ens, optimizer, augmentation
        )
        models.append((model, model_name, val_acc))
        val_accuracies.append(val_acc)

    # Тренируем модели с разными сидами для повышения разнообразия
    for i in range(2):
        tf.random.set_seed(42 + i * 10)
        model, history, val_acc = train_model(
            create_model_1, f"Deep CNN v{i+2}", X_train_ens, y_train_ens,
            X_val_ens, y_val_ens, 'adam', 'standard'
        )
        models.append((model, f"Deep CNN v{i+2}", val_acc))
        val_accuracies.append(val_acc)

    return models, val_accuracies

# %%
# Test Time Augmentation for ensemble
def predict_with_tta_ensemble(models, X_test, num_augmentations=8):
    """Apply TTA and ensemble predictions"""
    all_predictions = []

    test_datagen = ImageDataGenerator(
        rotation_range=12,
        width_shift_range=0.08,
        height_shift_range=0.08,
        horizontal_flip=True
    )

    for model, model_name, val_acc in models:
        model_predictions = []

        # Оригинальное предсказание
        pred_original = model.predict(X_test, verbose=0)
        model_predictions.append(pred_original)

        # Аугментированное предсказание
        for i in range(num_augmentations):
            X_test_aug = np.array([test_datagen.random_transform(x) for x in X_test])
            pred_aug = model.predict(X_test_aug, verbose=0)
            model_predictions.append(pred_aug)

        # Среднее время теста
        avg_pred = np.mean(model_predictions, axis=0)

        # Вес в зависимости от validation accuracy
        weighted_pred = avg_pred * val_acc
        all_predictions.append(weighted_pred)

        print(f"Generated predictions for {model_name} (weight: {val_acc:.4f})")

    # Ensemble all model predictions
    ensemble_pred = np.mean(all_predictions, axis=0)
    return ensemble_pred

# %%
# Тренируем модели
print("Starting ensemble training...")
models, val_accuracies = train_ensemble_cv()

print(f"\n{'='*60}")
print("ENSEMBLE SUMMARY")
print(f"{'='*60}")
for i, (model, name, acc) in enumerate(models):
    print(f"Model {i+1}: {name} - Validation Accuracy: {acc:.4f} ({acc*100:.2f}%)")

avg_val_acc = np.mean(val_accuracies)
print(f"\nAverage Individual Model Accuracy: {avg_val_acc:.4f} ({avg_val_acc*100:.2f}%)")

# Гененрируем предсказания
print(f"\n{'='*60}")
print("GENERATING ENSEMBLE PREDICTIONS")
print(f"{'='*60}")

ensemble_predictions = predict_with_tta_ensemble(models, X_test, num_augmentations=6)
y_pred_ensemble = np.argmax(ensemble_predictions, axis=1)

# Создаем файл для Kaggle
submission_df = pd.DataFrame({'Id': ids_test, 'label': y_pred_ensemble})
submission_df.to_csv('submission_ensemble_ultimate.csv', index=False)

print(f"\nEnsemble submission file 'submission_ensemble_ultimate.csv' created successfully!")
print(f"Expected ensemble accuracy: {avg_val_acc + 0.01:.4f}+ ({(avg_val_acc + 0.01)*100:.2f}%+)")

# Сохраняем предсказания каждой модели
individual_preds = {}
for i, (model, name, acc) in enumerate(models):
    pred = model.predict(X_test, verbose=0)
    individual_preds[f"{name}_pred"] = np.argmax(pred, axis=1)

# Выгружаем файл с анализом по каждой модели
pred_df = pd.DataFrame(individual_preds)
pred_df['ensemble_pred'] = y_pred_ensemble
pred_df['Id'] = ids_test
pred_df.to_csv('detailed_predictions_analysis.csv', index=False)

print("\nDetailed predictions analysis saved to 'detailed_predictions_analysis.csv'")
print("This file shows individual model predictions vs ensemble prediction for each test sample.")
# Out:
# Starting ensemble training...
# Ensemble training set: 14483 семплов
# Ensemble validation set: 2556 семплов
#
# ==================================================
# Training Deep CNN
# ==================================================
# Model parameters: 490,218
# Epoch 1/100
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 28s 127ms/step - accuracy: 0.4989 - loss: 2.1318 - val_accuracy: 0.1037 - val_loss: 3.1681 - learning_rate: 0.0010
# Epoch 2/100
#   1/113 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.6406 - loss: 1.5481
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/epoch_iterator.py:107: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self._interrupted_warning()
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6406 - loss: 1.5481 - val_accuracy: 0.1264 - val_loss: 3.1614 - learning_rate: 0.0010
# Epoch 3/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 5s 43ms/step - accuracy: 0.7189 - loss: 1.2710 - val_accuracy: 0.1416 - val_loss: 4.1157 - learning_rate: 0.0010
# Epoch 4/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7188 - loss: 1.1169 - val_accuracy: 0.1506 - val_loss: 4.1015 - learning_rate: 0.0010
# Epoch 5/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 6s 50ms/step - accuracy: 0.7527 - loss: 1.1349 - val_accuracy: 0.1072 - val_loss: 5.5358 - learning_rate: 0.0010
# Epoch 6/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7500 - loss: 1.1229 - val_accuracy: 0.1013 - val_loss: 5.9301 - learning_rate: 0.0010
# Epoch 7/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 10s 48ms/step - accuracy: 0.7777 - loss: 1.0138 - val_accuracy: 0.2363 - val_loss: 5.7871 - learning_rate: 0.0010
# Epoch 8/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8047 - loss: 0.9484 - val_accuracy: 0.2332 - val_loss: 5.6535 - learning_rate: 0.0010
# Epoch 9/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 9s 43ms/step - accuracy: 0.7965 - loss: 0.9148 - val_accuracy: 0.7473 - val_loss: 0.9692 - learning_rate: 0.0010
# Epoch 10/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8516 - loss: 0.7281 - val_accuracy: 0.7547 - val_loss: 0.9548 - learning_rate: 0.0010
# Epoch 11/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 10s 43ms/step - accuracy: 0.8132 - loss: 0.8241 - val_accuracy: 0.8611 - val_loss: 0.7051 - learning_rate: 0.0010
# Epoch 12/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8516 - loss: 0.7590 - val_accuracy: 0.8451 - val_loss: 0.7206 - learning_rate: 0.0010
# Epoch 13/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 10s 44ms/step - accuracy: 0.8396 - loss: 0.7400 - val_accuracy: 0.8470 - val_loss: 0.6835 - learning_rate: 0.0010
# Epoch 14/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8516 - loss: 0.6761 - val_accuracy: 0.8474 - val_loss: 0.6840 - learning_rate: 0.0010
# Epoch 15/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 10s 44ms/step - accuracy: 0.8259 - loss: 0.7179 - val_accuracy: 0.8478 - val_loss: 0.6404 - learning_rate: 0.0010
# Epoch 16/100
#   1/113 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.7891 - loss: 0.7764
# Epoch 16: ReduceLROnPlateau reducing learning rate to 0.0003000000142492354.
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7891 - loss: 0.7764 - val_accuracy: 0.8549 - val_loss: 0.6221 - learning_rate: 0.0010
# Epoch 17/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 10s 45ms/step - accuracy: 0.8476 - loss: 0.6418 - val_accuracy: 0.8662 - val_loss: 0.5912 - learning_rate: 3.0000e-04
# Epoch 18/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8516 - loss: 0.6766 - val_accuracy: 0.8678 - val_loss: 0.5884 - learning_rate: 3.0000e-04
# Epoch 19/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 5s 47ms/step - accuracy: 0.8576 - loss: 0.5966 - val_accuracy: 0.8584 - val_loss: 0.5936 - learning_rate: 3.0000e-04
# Epoch 20/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8672 - loss: 0.5806 - val_accuracy: 0.8505 - val_loss: 0.6065 - learning_rate: 3.0000e-04
# Epoch 21/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 9s 43ms/step - accuracy: 0.8553 - loss: 0.5841 - val_accuracy: 0.8564 - val_loss: 0.5861 - learning_rate: 3.0000e-04
# Epoch 22/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8906 - loss: 0.6355 - val_accuracy: 0.8572 - val_loss: 0.5843 - learning_rate: 3.0000e-04
# Epoch 23/100
# 112/113 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.8664 - loss: 0.5625
# Epoch 23: ReduceLROnPlateau reducing learning rate to 9.000000427477062e-05.
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 6s 51ms/step - accuracy: 0.8664 - loss: 0.5626 - val_accuracy: 0.8517 - val_loss: 0.5850 - learning_rate: 3.0000e-04
# Epoch 24/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8750 - loss: 0.5601 - val_accuracy: 0.8517 - val_loss: 0.5822 - learning_rate: 9.0000e-05
# Epoch 25/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 10s 52ms/step - accuracy: 0.8695 - loss: 0.5370 - val_accuracy: 0.8760 - val_loss: 0.5307 - learning_rate: 9.0000e-05
# Epoch 26/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8203 - loss: 0.6259 - val_accuracy: 0.8744 - val_loss: 0.5321 - learning_rate: 9.0000e-05
# Epoch 27/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 5s 43ms/step - accuracy: 0.8692 - loss: 0.5389 - val_accuracy: 0.8795 - val_loss: 0.5235 - learning_rate: 9.0000e-05
# Epoch 28/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8672 - loss: 0.6175 - val_accuracy: 0.8795 - val_loss: 0.5213 - learning_rate: 9.0000e-05
# Epoch 29/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 5s 45ms/step - accuracy: 0.8699 - loss: 0.5302 - val_accuracy: 0.8603 - val_loss: 0.5525 - learning_rate: 9.0000e-05
# Epoch 30/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9062 - loss: 0.4690 - val_accuracy: 0.8568 - val_loss: 0.5580 - learning_rate: 9.0000e-05
# Epoch 31/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 10s 43ms/step - accuracy: 0.8747 - loss: 0.5155 - val_accuracy: 0.8631 - val_loss: 0.5529 - learning_rate: 9.0000e-05
# Epoch 32/100
#   1/113 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - accuracy: 0.8516 - loss: 0.4965
# Epoch 32: ReduceLROnPlateau reducing learning rate to 2.700000040931627e-05.
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8516 - loss: 0.4965 - val_accuracy: 0.8619 - val_loss: 0.5543 - learning_rate: 9.0000e-05
# Epoch 33/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 6s 52ms/step - accuracy: 0.8797 - loss: 0.5083 - val_accuracy: 0.8807 - val_loss: 0.5108 - learning_rate: 2.7000e-05
# Epoch 34/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8672 - loss: 0.5084 - val_accuracy: 0.8799 - val_loss: 0.5091 - learning_rate: 2.7000e-05
# Epoch 35/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 10s 49ms/step - accuracy: 0.8786 - loss: 0.5078 - val_accuracy: 0.8725 - val_loss: 0.5227 - learning_rate: 2.7000e-05
# Epoch 36/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8438 - loss: 0.6182 - val_accuracy: 0.8717 - val_loss: 0.5231 - learning_rate: 2.7000e-05
# Epoch 37/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 5s 42ms/step - accuracy: 0.8751 - loss: 0.5089 - val_accuracy: 0.8795 - val_loss: 0.5083 - learning_rate: 2.7000e-05
# Epoch 38/100
#   1/113 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - accuracy: 0.8828 - loss: 0.4454
# Epoch 38: ReduceLROnPlateau reducing learning rate to 8.100000013655517e-06.
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8828 - loss: 0.4454 - val_accuracy: 0.8799 - val_loss: 0.5087 - learning_rate: 2.7000e-05
# Epoch 39/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 5s 44ms/step - accuracy: 0.8732 - loss: 0.5047 - val_accuracy: 0.8779 - val_loss: 0.5098 - learning_rate: 8.1000e-06
# Epoch 40/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8984 - loss: 0.4497 - val_accuracy: 0.8779 - val_loss: 0.5096 - learning_rate: 8.1000e-06
# Epoch 41/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 9s 43ms/step - accuracy: 0.8797 - loss: 0.4969 - val_accuracy: 0.8779 - val_loss: 0.5089 - learning_rate: 8.1000e-06
# Epoch 42/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8438 - loss: 0.5998 - val_accuracy: 0.8775 - val_loss: 0.5089 - learning_rate: 8.1000e-06
# Epoch 43/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.8766 - loss: 0.5000
# Epoch 43: ReduceLROnPlateau reducing learning rate to 2.429999949526973e-06.
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 10s 42ms/step - accuracy: 0.8766 - loss: 0.5000 - val_accuracy: 0.8783 - val_loss: 0.5087 - learning_rate: 8.1000e-06
# Epoch 44/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8828 - loss: 0.5221 - val_accuracy: 0.8791 - val_loss: 0.5086 - learning_rate: 2.4300e-06
# Epoch 45/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 10s 42ms/step - accuracy: 0.8792 - loss: 0.4947 - val_accuracy: 0.8787 - val_loss: 0.5046 - learning_rate: 2.4300e-06
# Epoch 46/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8984 - loss: 0.4430 - val_accuracy: 0.8787 - val_loss: 0.5044 - learning_rate: 2.4300e-06
# Epoch 47/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 6s 50ms/step - accuracy: 0.8773 - loss: 0.5005 - val_accuracy: 0.8787 - val_loss: 0.5041 - learning_rate: 2.4300e-06
# Epoch 48/100
#   1/113 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - accuracy: 0.8984 - loss: 0.4555
# Epoch 48: ReduceLROnPlateau reducing learning rate to 7.289999985005124e-07.
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8984 - loss: 0.4555 - val_accuracy: 0.8787 - val_loss: 0.5041 - learning_rate: 2.4300e-06
# Epoch 48: early stopping
# Restoring model weights from the end of the best epoch: 33.
# Deep CNN - Validation Accuracy: 0.8807 (88.07%)
# Best epoch: 33
#
# ==================================================
# Training Wide CNN
# ==================================================
# Model parameters: 1,354,954
# Epoch 1/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 24s 119ms/step - accuracy: 0.4203 - loss: 11.7459 - val_accuracy: 0.1373 - val_loss: 7.2285 - learning_rate: 0.0010
# Epoch 2/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6484 - loss: 5.7166 - val_accuracy: 0.0994 - val_loss: 7.0633 - learning_rate: 0.0010
# Epoch 3/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 5s 45ms/step - accuracy: 0.6446 - loss: 4.3984 - val_accuracy: 0.0986 - val_loss: 7.2413 - learning_rate: 0.0010
# Epoch 4/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7812 - loss: 1.7810 - val_accuracy: 0.1236 - val_loss: 6.7047 - learning_rate: 0.0010
# Epoch 5/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 10s 45ms/step - accuracy: 0.7011 - loss: 1.6201 - val_accuracy: 0.2003 - val_loss: 2.9509 - learning_rate: 0.0010
# Epoch 6/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7109 - loss: 1.2156 - val_accuracy: 0.2786 - val_loss: 2.6472 - learning_rate: 0.0010
# Epoch 7/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 11s 51ms/step - accuracy: 0.7384 - loss: 1.0427 - val_accuracy: 0.5532 - val_loss: 1.4707 - learning_rate: 0.0010
# Epoch 8/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.
100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9219 - loss: 0.3410 - val_accuracy: 0.8795 - val_loss: 0.4104 - learning_rate: 2.4300e-06
# Epoch 53/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 10s 53ms/step - accuracy: 0.8733 - loss: 0.4067 - val_accuracy: 0.8799 - val_loss: 0.4092 - learning_rate: 2.4300e-06
# Epoch 54/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8438 - loss: 0.5265 - val_accuracy: 0.8795 - val_loss: 0.4091 - learning_rate: 2.4300e-06
# Epoch 55/100
# 112/113 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.8706 - loss: 0.4118
# Epoch 55: ReduceLROnPlateau reducing learning rate to 7.289999985005124e-07.
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 5s 45ms/step - accuracy: 0.8707 - loss: 0.4118 - val_accuracy: 0.8795 - val_loss: 0.4093 - learning_rate: 2.4300e-06
# Epoch 56/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8750 - loss: 0.4601 - val_accuracy: 0.8795 - val_loss: 0.4092 - learning_rate: 7.2900e-07
# Epoch 57/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 5s 48ms/step - accuracy: 0.8699 - loss: 0.4006 - val_accuracy: 0.8795 - val_loss: 0.4093 - learning_rate: 7.2900e-07
# Epoch 58/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8750 - loss: 0.4213 - val_accuracy: 0.8799 - val_loss: 0.4092 - learning_rate: 7.2900e-07
# Epoch 59/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 9s 45ms/step - accuracy: 0.8709 - loss: 0.4116 - val_accuracy: 0.8799 - val_loss: 0.4093 - learning_rate: 7.2900e-07
# Epoch 60/100
#   1/113 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - accuracy: 0.8281 - loss: 0.4810
# Epoch 60: ReduceLROnPlateau reducing learning rate to 2.1870000637136398e-07.
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8281 - loss: 0.4810 - val_accuracy: 0.8799 - val_loss: 0.4093 - learning_rate: 7.2900e-07
# Epoch 60: early stopping
# Restoring model weights from the end of the best epoch: 45.
# Wide CNN - Validation Accuracy: 0.8818 (88.18%)
# Best epoch: 45
#
# ==================================================
# Training ResNet-inspired
# ==================================================
# Model parameters: 178,858
# Epoch 1/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 22s 106ms/step - accuracy: 0.5059 - loss: 1.7383 - val_accuracy: 0.0986 - val_loss: 3.6628 - learning_rate: 0.0010
# Epoch 2/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7266 - loss: 0.9808 - val_accuracy: 0.0986 - val_loss: 3.6693 - learning_rate: 0.0010
# Epoch 3/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 5s 40ms/step - accuracy: 0.7247 - loss: 0.9284 - val_accuracy: 0.0986 - val_loss: 5.1065 - learning_rate: 0.0010
# Epoch 4/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7578 - loss: 0.8014 - val_accuracy: 0.0986 - val_loss: 5.2791 - learning_rate: 0.0010
# Epoch 5/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 6s 47ms/step - accuracy: 0.7451 - loss: 0.8370 - val_accuracy: 0.1655 - val_loss: 4.8478 - learning_rate: 0.0010
# Epoch 6/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7656 - loss: 0.7876 - val_accuracy: 0.1667 - val_loss: 4.8090 - learning_rate: 0.0010
# Epoch 7/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 5s 40ms/step - accuracy: 0.7877 - loss: 0.7214 - val_accuracy: 0.5086 - val_loss: 2.0452 - learning_rate: 0.0010
# Epoch 8/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8594 - loss: 0.5578 - val_accuracy: 0.5070 - val_loss: 2.0490 - learning_rate: 0.0010
# Epoch 9/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 5s 40ms/step - accuracy: 0.8040 - loss: 0.6433 - val_accuracy: 0.6987 - val_loss: 0.9187 - learning_rate: 0.0010
# Epoch 10/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7188 - loss: 0.9137 - val_accuracy: 0.6929 - val_loss: 0.9713 - learning_rate: 0.0010
# Epoch 11/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 5s 46ms/step - accuracy: 0.8182 - loss: 0.6097 - val_accuracy: 0.8005 - val_loss: 0.6705 - learning_rate: 0.0010
# Epoch 12/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8516 - loss: 0.5300 - val_accuracy: 0.8161 - val_loss: 0.6417 - learning_rate: 0.0010
# Epoch 13/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 5s 41ms/step - accuracy: 0
100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8672 - loss: 0.3818 - val_accuracy: 0.8642 - val_loss: 0.4551 - learning_rate: 9.0000e-05
# Epoch 37/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 9s 40ms/step - accuracy: 0.8853 - loss: 0.3793 - val_accuracy: 0.8744 - val_loss: 0.4361 - learning_rate: 9.0000e-05
# Epoch 38/100
#   1/113 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.8984 - loss: 0.3622
# Epoch 38: ReduceLROnPlateau reducing learning rate to 2.700000040931627e-05.
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8984 - loss: 0.3622 - val_accuracy: 0.8756 - val_loss: 0.4338 - learning_rate: 9.0000e-05
# Epoch 39/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 6s 48ms/step - accuracy: 0.8875 - loss: 0.3749 - val_accuracy: 0.8736 - val_loss: 0.4450 - learning_rate: 2.7000e-05
# Epoch 40/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8906 - loss: 0.3841 - val_accuracy: 0.8740 - val_loss: 0.4455 - learning_rate: 2.7000e-05
# Epoch 41/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 10s 49ms/step - accuracy: 0.8896 - loss: 0.3610 - val_accuracy: 0.8576 - val_loss: 0.4812 - learning_rate: 2.7000e-05
# Epoch 42/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8906 - loss: 0.3314 - val_accuracy: 0.8572 - val_loss: 0.4808 - learning_rate: 2.7000e-05
# Epoch 43/100
# 112/113 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.8839 - loss: 0.3766
# Epoch 43: ReduceLROnPlateau reducing learning rate to 8.100000013655517e-06.
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 5s 41ms/step - accuracy: 0.8839 - loss: 0.3766 - val_accuracy: 0.8674 - val_loss: 0.4545 - learning_rate: 2.7000e-05
# Epoch 44/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8828 - loss: 0.3786 - val_accuracy: 0.8674 - val_loss: 0.4545 - learning_rate: 8.1000e-06
# Epoch 45/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 5s 43ms/step - accuracy: 0.8829 - loss: 0.3802 - val_accuracy: 0.8689 - val_loss: 0.4522 - learning_rate: 8.1000e-06
# Epoch 46/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8828 - loss: 0.3957 - val_accuracy: 0.8689 - val_loss: 0.4526 - learning_rate: 8.1000e-06
# Epoch 47/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 9s 41ms/step - accuracy: 0.8877 - loss: 0.3767 - val_accuracy: 0.8756 - val_loss: 0.4415 - learning_rate: 8.1000e-06
# Epoch 48/100
#   1/113 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.8984 - loss: 0.3417
# Epoch 48: ReduceLROnPlateau reducing learning rate to 2.429999949526973e-06.
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8984 - loss: 0.3417 - val_accuracy: 0.8756 - val_loss: 0.4414 - learning_rate: 8.1000e-06
# Epoch 48: early stopping
# Restoring model weights from the end of the best epoch: 33.
# ResNet-inspired - Validation Accuracy: 0.8756 (87.56%)
# Best epoch: 33
#
# ==================================================
# Training Compact Deep
# ==================================================
# Model parameters: 726,106
# Epoch 1/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 26s 131ms/step - accuracy: 0.5131 - loss: 1.8017 - val_accuracy: 0.1025 - val_loss: 3.0473 - learning_rate: 0.0100
# Epoch 2/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7891 - loss: 0.8451 - val_accuracy: 0.1049 - val_loss: 3.0301 - learning_rate: 0.0100
# Epoch 3/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 25s 56ms/step - accuracy: 0.7330 - loss: 0.9803 - val_accuracy: 0.1491 - val_loss: 3.6230 - learning_rate: 0.0100
# Epoch 4/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7812 - loss: 0.7829 - val_accuracy: 0.1424 - val_loss: 3.7248 - learning_rate: 0.0100
# Epoch 5/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 6s 49ms/step - accuracy: 0.7635 - loss: 0.8714 - val_accuracy: 0.2516 - val_loss: 2.4611 - learning_rate: 0.0100
# Epoch 6/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7891 - loss: 0.8106 - val_accuracy: 0.2328 - val_loss: 2.5322 - learning_rate: 0.0100
# Epoch 7/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 10s 51ms/step - accuracy: 0.7814 - loss: 0.8009 - val_accuracy: 0.6236 - val_loss: 1.2163 - learning_rate: 0.0100
# Epoch 8/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8125 - loss: 0.7140 - val_accuracy: 0.6017 - val_loss: 1.2758 - learning_rate: 0.0100
# Epoch 9/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 10s 56ms/step - accuracy: 0.7939 - loss: 0.7698 - val_accuracy: 0.7383 - val_loss: 0.9259 - learning_rate: 0.0100
# Epoch 10/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7734 - loss: 0.7654 - val_accuracy: 0.7344 - val_loss: 0.9392 - learning_rate: 0.0100
# Epoch 11/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 10s 57ms/step - accuracy: 0.8164 - loss: 0.7063 - val_accuracy: 0.7578 - val_loss: 0.8703 - learning_rate: 0.0100
# Epoch 12/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7812 - loss: 0.9099 - val_accuracy: 0.7508 - val_loss: 0.9095 - learning_rate: 0.0100
# Epoch 13/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 9s 50ms/step - accuracy: 0.8140 - loss: 0.6876 - val_accuracy: 0.6847 - val_loss: 1.1740 - learning_rate: 0.0100
# Epoch 14/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7656 - loss: 0.6901 - val_accuracy: 0.7050 - val_loss: 1.1015 - learning_rate: 0.0100
# Epoch 15/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 6s 53ms/step - accuracy: 0.8208 - loss: 0.6728 - val_accuracy: 0.8126 - val_loss: 0.7635 - learning_rate: 0.0100
# Epoch 16/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8047 - loss: 0.6301 - val_accuracy: 0.8181 - val_loss: 0.7258 - learning_rate: 0.0100
# Epoch 17/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 10s 56ms/step - accuracy: 0.8352 - loss: 0.6327 - val_accuracy: 0.5575 - val_loss: 1.7291 - learning_rate: 0.0100
# Epoch 18/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8594 - loss: 0.5458 - val_accuracy: 0.5536 - val_loss: 1.7236 - learning_rate: 0.0100
# Epoch 19/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 6s 50ms/step - accuracy: 0.8347 - loss: 0.6178 - val_accuracy: 0.6678 - val_loss: 1.3258 - learning_rate: 0.0100
# Epoch 20/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8438 - loss: 0.5987 - val_accuracy: 0.6377 - val_loss: 1.4457 - learning_rate: 0.0100
# Epoch 21/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 6s 56ms/step - accuracy: 0.8380 - loss: 0.6050 - val_accuracy: 0.8670 - val_loss: 0.5602 - learning_rate: 0.0100
# Epoch 22/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7891 - loss: 0.6002 - val_accuracy: 0.8560 - val_loss: 0.5894 - learning_rate: 0.0100
# Epoch 23/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 6s 50ms/step - accuracy: 0.8463 - loss: 0.5724 - val_accuracy: 0.6694 - val_loss: 0.9843 - learning_rate: 0.0100
# Epoch 24/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8984 - loss: 0.4892 - val_accuracy: 0.6667 - val_loss: 1.0072 - learning_rate: 0.0100
# Epoch 25/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 10s 50ms/step - accuracy: 0.8466 - loss: 0.5568 - val_accuracy: 0.8412 - val_loss: 0.5852 - learning_rate: 0.0100
# Epoch 26/100
#   1/113 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - accuracy: 0.8359 - loss: 0.4962
# Epoch 26: ReduceLROnPlateau reducing learning rate to 0.0029999999329447745.
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8359 - loss: 0.4962 - val_accuracy: 0.8423 - val_loss: 0.5817 - learning_rate: 0.0100
# Epoch 27/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 10s 50ms/step - accuracy: 0.8535 - loss: 0.5436 - val_accuracy: 0.8357 - val_loss: 0.6391 - learning_rate: 0.0030
# Epoch 28/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9219 - loss: 0.4413 - val_accuracy: 0.8408 - val_loss: 0.6301 - learning_rate: 0.0030
# Epoch 29/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 6s 56ms/step - accuracy: 0.8637 - loss: 0.5125 - val_accuracy: 0.8494 - val_loss: 0.5939 - learning_rate: 0.0030
# Epoch 30/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.

# 113/113 ━━━━━━━━━━━━━━━━━━━━ 10s 56ms/step - accuracy: 0.8840 - loss: 0.4395 - val_accuracy: 0.8725 - val_loss: 0.5066 - learning_rate: 2.7000e-04
# Epoch 51: early stopping
# Restoring model weights from the end of the best epoch: 36.
# Compact Deep - Validation Accuracy: 0.8928 (89.28%)
# Best epoch: 36
#
# ==================================================
# Training Deep CNN v2
# ==================================================
# Model parameters: 490,218
# Epoch 1/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 24s 109ms/step - accuracy: 0.4849 - loss: 2.1506 - val_accuracy: 0.0986 - val_loss: 3.1661 - learning_rate: 0.0010
# Epoch 2/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7344 - loss: 1.2490 - val_accuracy: 0.0986 - val_loss: 3.1821 - learning_rate: 0.0010
# Epoch 3/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 7s 46ms/step - accuracy: 0.7148 - loss: 1.2845 - val_accuracy: 0.0982 - val_loss: 4.7589 - learning_rate: 0.0010
# Epoch 4/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.6875 - loss: 1.2928 - val_accuracy: 0.0982 - val_loss: 4.6599 - learning_rate: 0.0010
# Epoch 5/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 7s 62ms/step - accuracy: 0.7662 - loss: 1.0841 - val_accuracy: 0.1925 - val_loss: 3.2760 - learning_rate: 0.0010
# Epoch 6/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8125 - loss: 0.9353 - val_accuracy: 0.1718 - val_loss: 3.3487 - learning_rate: 0.0010
# Epoch 7/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 7s 64ms/step - accuracy: 0.7680 - loss: 1.0333 - val_accuracy: 0.5063 - val_loss: 2.0885 - learning_rate: 0.0010
# Epoch 8/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8359 - loss: 0.9219 - val_accuracy: 0.5070 - val_loss: 2.0729 - learning_rate: 0.0010
# Epoch 9/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 8s 45ms/step - accuracy: 0.8034 - loss: 0.9098 - val_accuracy: 0.7038 - val_loss: 1.1352 - learning_rate: 0.0010
# Epoch 10/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7656 - loss: 0.9083 - val_accuracy: 0.7218 - val_loss: 1.0673 - learning_rate: 0.0010
# Epoch 11/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 10s 46ms/step - accuracy: 0.8212 - loss: 0.8103 - val_accuracy: 0.8232 - val_loss: 0.7838 - learning_rate: 0.0010
# Epoch 12/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8047 - loss: 0.7938 - val_accuracy: 0.8165 - val_loss: 0.7920 - learning_rate: 0.0010
# Epoch 13/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 6s 54ms/step - accuracy: 0.8215 - loss: 0.7775 - val_accuracy: 0.8462 - val_loss: 0.7130 - learning_rate: 0.0010
# Epoch 14/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8438 - loss: 0.6939 - val_accuracy: 0.8466 - val_loss: 0.7045 - learning_rate: 0.0010
# Epoch 15/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 9s 49ms/step - accuracy: 0.8359 - loss: 0.7076 - val_accuracy: 0.8623 - val_loss: 0.6212 - learning_rate: 0.0010
# Epoch 16/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8359 - loss: 0.6487 - val_accuracy: 0.8611 - val_loss: 0.6237 - learning_rate: 0.0010
# Epoch 17/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 6s 49ms/step - accuracy: 0.8391 - loss: 0.6635 - val_accuracy: 0.8537 - val_loss: 0.6129 - learning_rate: 0.0010
# Epoch 18/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8906 - loss: 0.5053 - val_accuracy: 0.8513 - val_loss: 0.6145 - learning_rate: 0.0010
# Epoch 19/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 10s 54ms/step - accuracy: 0.8399 - loss: 0.6309 - val_accuracy: 0.8478 - val_loss: 0.5837 - learning_rate: 0.0010
# Epoch 20/100
#   1/113 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - accuracy: 0.8516 - loss: 0.5596
# Epoch 20: ReduceLROnPlateau reducing learning rate to 0.0003000000142492354.
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8516 - loss: 0.5596 - val_accuracy: 0.8490 - val_loss: 0.5870 - learning_rate: 0.0010
# Epoch 21/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 10s 59ms/step - accuracy: 0.8611 - loss: 0.5583 - val_accuracy: 0.8666 - val_loss: 0.5330 - learning_rate: 3.0000e-04
# Epoch 22/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8359 - loss: 0.6195 - val_accuracy: 0.8615 - val_loss: 0.5403 - learning_rate: 3.0000e-04
# Epoch 23/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 5s 45ms/step - accuracy: 0.8671 - loss: 0.5367 - val_accuracy: 0.8760 - val_loss: 0.5206 - learning_rate: 3.0000e-04
# Epoch 24/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8828 - loss: 0.4654 - val_accuracy: 0.8744 - val_loss: 0.5215 - learning_rate: 3.0000e-04
# Epoch 25/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 10s 45ms/step - accuracy: 0.8659 - loss: 0.5255 - val_accuracy: 0.8705 - val_loss: 0.5265 - learning_rate: 3.0000e-04
# Epoch 26/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8828 - loss: 0.4345 - val_accuracy: 0.8705 - val_loss: 0.5234 - learning_rate: 3.0000e-04
# Epoch 27/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 6s 49ms/step - accuracy: 0.8691 - loss: 0.5066 - val_accuracy: 0.8658 - val_loss: 0.4980 - learning_rate: 3.0000e-04
# Epoch 28/100
#   1/113 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - accuracy: 0.8359 - loss: 0.6165
# Epoch 28: ReduceLROnPlateau reducing learning rate to 9.000000427477062e-05.
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8359 - loss: 0.6165 - val_accuracy: 0.8670 - val_loss: 0.4996 - learning_rate: 3.0000e-04
# Epoch 29/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 5s 46ms/step - accuracy: 0.8713 - loss: 0.4895 - val_accuracy: 0.8556 - val_loss: 0.5068 - learning_rate: 9.0000e-05
# Epoch 30/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8672 - loss: 0.4292 - val_accuracy: 0.8541 - val_loss: 0.5127 - learning_rate: 9.0000e-05
# Epoch 31/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 11s 52ms/step - accuracy: 0.8803 - loss: 0.4745 - val_accuracy: 0.8846 - val_loss: 0.4599 - learning_rate: 9.0000e-05
# Epoch 32/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9375 - loss: 0.3958 - val_accuracy: 0.8826 - val_loss: 0.4610 - learning_rate: 9.0000e-05
# Epoch 33/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 10s 53ms/step - accuracy: 0.8750 - loss: 0.4831 - val_accuracy: 0.8642 - val_loss: 0.4919 - learning_rate: 9.0000e-05
# Epoch 34/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8906 - loss: 0.4554 - val_accuracy: 0.8642 - val_loss: 0.4922 - learning_rate: 9.0000e-05
# Epoch 35/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 9s 46ms/step - accuracy: 0.8812 - loss: 0.4641 - val_accuracy: 0.8638 - val_loss: 0.4794 - learning_rate: 9.0000e-05
# Epoch 36/100
#   1/113 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - accuracy: 0.8906 - loss: 0.4662
# Epoch 36: ReduceLROnPlateau reducing learning rate to 2.700000040931627e-05.
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8906 - loss: 0.4662 - val_accuracy: 0.8642 - val_loss: 0.4812 - learning_rate: 9.0000e-05
# Epoch 37/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 9s 46ms/step - accuracy: 0.8820 - loss: 0.4559 - val_accuracy: 0.8795 - val_loss: 0.4563 - learning_rate: 2.7000e-05
# Epoch 38/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9141 - loss: 0.3651 - val_accuracy: 0.8795 - val_loss: 0.4559 - learning_rate: 2.7000e-05
# Epoch 39/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 6s 53ms/step - accuracy: 0.8809 - loss: 0.4583 - val_accuracy: 0.8815 - val_loss: 0.4537 - learning_rate: 2.7000e-05
# Epoch 40/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8750 - loss: 0.4388 - val_accuracy: 0.8822 - val_loss: 0.4528 - learning_rate: 2.7000e-05
# Epoch 41/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.8789 - loss: 0.4517
# Epoch 41: ReduceLROnPlateau reducing learning rate to 8.100000013655517e-06.
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 10s 54ms/step - accuracy: 0.8789 - loss: 0.4517 - val_accuracy: 0.8642 - val_loss: 0.4805 - learning_rate: 2.7000e-05
# Epoch 42/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8438 - loss: 0.5482 - val_accuracy: 0.8646 - val_loss: 0.4802 - learning_rate: 8.1000e-06
# Epoch 43/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 5s 45ms/step - accuracy: 0.8809 - loss: 0.4490 - val_accuracy: 0.8732 - val_loss: 0.4674 - learning_rate: 8.1000e-06
# Epoch 44/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8359 - loss: 0.5438 - val_accuracy: 0.8732 - val_loss: 0.4672 - learning_rate: 8.1000e-06
# Epoch 45/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 5s 48ms/step - accuracy: 0.8816 - loss: 0.4483 - val_accuracy: 0.8760 - val_loss: 0.4608 - learning_rate: 8.1000e-06
# Epoch 46/100
#   1/113 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - accuracy: 0.9219 - loss: 0.3889
# Epoch 46: ReduceLROnPlateau reducing learning rate to 2.429999949526973e-06.
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9219 - loss: 0.3889 - val_accuracy: 0.8764 - val_loss: 0.4603 - learning_rate: 8.1000e-06
# Epoch 46: early stopping
# Restoring model weights from the end of the best epoch: 31.
# Deep CNN v2 - Validation Accuracy: 0.8846 (88.46%)
# Best epoch: 31
#
# ==================================================
# Training Deep CNN v3
# ==================================================
# Model parameters: 490,218
# Epoch 1/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 24s 111ms/step - accuracy: 0.4765 - loss: 2.1629 - val_accuracy: 0.1667 - val_loss: 2.8921 - learning_rate: 0.0010
# Epoch 2/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6484 - loss: 1.4423 - val_accuracy: 0.1796 - val_loss: 2.9093 - learning_rate: 0.0010
# Epoch 3/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 7s 50ms/step - accuracy: 0.7054 - loss: 1.3339 - val_accuracy: 0.1248 - val_loss: 3.9290 - learning_rate: 0.0010
# Epoch 4/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7344 - loss: 1.2247 - val_accuracy: 0.1291 - val_loss: 3.9135 - learning_rate: 0.0010
# Epoch 5/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 9s 46ms/step - accuracy: 0.7443 - loss: 1.1420 - val_accuracy: 0.2034 - val_loss: 4.0811 - learning_rate: 0.0010
# Epoch 6/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7734 - loss: 0.9908 - val_accuracy: 0.2089 - val_loss: 4.0951 - learning_rate: 0.0010
# Epoch 7/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 6s 54ms/step - accuracy: 0.7776 - loss: 1.0226 - val_accuracy: 0.4863 - val_loss: 2.0575 - learning_rate: 0.0010
# Epoch 8/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7500 - loss: 1.0306 - val_accuracy: 0.4855 - val_loss: 2.0542 - learning_rate: 0.0010
# Epoch 9/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 10s 54ms/step - accuracy: 0.7933 - loss: 0.9387 - val_accuracy: 0.7062 - val_loss: 1.1501 - learning_rate: 0.0010
# Epoch 10/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7969 - loss: 0.9291 - val_accuracy: 0.7066 - val_loss: 1.1561 - learning_rate: 0.0010
# Epoch 11/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 5s 45ms/step - accuracy: 0.8073 - loss: 0.8619 - val_accuracy: 0.8310 - val_loss: 0.7653 - learning_rate: 0.0010
# Epoch 12/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7812 - loss: 0.8285 - val_accuracy: 0.8322 - val_loss: 0.7714 - learning_rate: 0.0010
# Epoch 13/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 10s 49ms/step - accuracy: 0.8084 - loss: 0.8204 - val_accuracy: 0.8419 - val_loss: 0.7320 - learning_rate: 0.0010
# Epoch 14/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8203 - loss: 0.7614 - val_accuracy: 0.8427 - val_loss: 0.7342 - learning_rate: 0.0010
# Epoch 15/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 10s 53ms/step - accuracy: 0.8186 - loss: 0.7559 - val_accuracy: 0.8533 - val_loss: 0.6426 - learning_rate: 0.0010
# Epoch 16/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8750 - loss: 0.5955 - val_accuracy: 0.8537 - val_loss: 0.6481 - learning_rate: 0.0010
# Epoch 17/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 5s 45ms/step - accuracy: 0.8380 - loss: 0.6740 - val_accuracy: 0.8048 - val_loss: 0.6866 - learning_rate: 0.0010
# Epoch 18/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8203 - loss: 0.7419 - val_accuracy: 0.8153 - val_loss: 0.6721 - learning_rate: 0.0010
# Epoch 19/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 6s 53ms/step - accuracy: 0.8398 - loss: 0.6314 - val_accuracy: 0.8650 - val_loss: 0.5713 - learning_rate: 0.0010
# Epoch 20/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8594 - loss: 0.5914 - val_accuracy: 0.8654 - val_loss: 0.5711 - learning_rate: 0.0010
# Epoch 21/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 10s 52ms/step - accuracy: 0.8460 - loss: 0.6023 - val_accuracy: 0.8623 - val_loss: 0.5452 - learning_rate: 0.0010
# Epoch 22/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8750 - loss: 0.5265 - val_accuracy: 0.8627 - val_loss: 0.5442 - learning_rate: 0.0010
# Epoch 23/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 5s 45ms/step - accuracy: 0.8458 - loss: 0.5731 - val_accuracy: 0.8470 - val_loss: 0.5534 - learning_rate: 0.0010
# Epoch 24/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8750 - loss: 0.4539 - val_accuracy: 0.8533 - val_loss: 0.5469 - learning_rate: 0.0010
# Epoch 25/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.8558 - loss: 0.5397
# Epoch 25: ReduceLROnPlateau reducing learning rate to 0.0003000000142492354.
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 6s 51ms/step - accuracy: 0.8558 - loss: 0.5397 - val_accuracy: 0.8431 - val_loss: 0.5648 - learning_rate: 0.0010
# Epoch 26/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8203 - loss: 0.6307 - val_accuracy: 0.8462 - val_loss: 0.5605 - learning_rate: 3.0000e-04
# Epoch 27/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 9s 46ms/step - accuracy: 0.8647 - loss: 0.4898 - val_accuracy: 0.8772 - val_loss: 0.4402 - learning_rate: 3.0000e-04
# Epoch 28/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8594 - loss: 0.5507 - val_accuracy: 0.8826 - val_loss: 0.4403 - learning_rate: 3.0000e-04
# Epoch 29/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 6s 53ms/step - accuracy: 0.8765 - loss: 0.4560 - val_accuracy: 0.8783 - val_loss: 0.4541 - learning_rate: 3.0000e-04
# Epoch 30/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9141 - loss: 0.3864 - val_accuracy: 0.8807 - val_loss: 0.4495 - learning_rate: 3.0000e-04
# Epoch 31/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 10s 54ms/step - accuracy: 0.8728 - loss: 0.4623 - val_accuracy: 0.8858 - val_loss: 0.4182 - learning_rate: 3.0000e-04
# Epoch 32/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8750 - loss: 0.4237 - val_accuracy: 0.8807 - val_loss: 0.4220 - learning_rate: 3.0000e-04
# Epoch 33/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 5s 45ms/step - accuracy: 0.8769 - loss: 0.4313 - val_accuracy: 0.8858 - val_loss: 0.4205 - learning_rate: 3.0000e-04
# Epoch 34/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8516 - loss: 0.4790 - val_accuracy: 0.8862 - val_loss: 0.4196 - learning_rate: 3.0000e-04
# Epoch 35/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 10s 48ms/step - accuracy: 0.8868 - loss: 0.4219 - val_accuracy: 0.8842 - val_loss: 0.4035 - learning_rate: 3.0000e-04
# Epoch 36/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8828 - loss: 0.4122 - val_accuracy: 0.8846 - val_loss: 0.4036 - learning_rate: 3.0000e-04
# Epoch 37/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 5s 48ms/step - accuracy: 0.8796 - loss: 0.4243 - val_accuracy: 0.8959 - val_loss: 0.3873 - learning_rate: 3.0000e-04
# Epoch 38/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9141 - loss: 0.3638 - val_accuracy: 0.8912 - val_loss: 0.3959 - learning_rate: 3.0000e-04
# Epoch 39/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 5s 48ms/step - accuracy: 0.8783 - loss: 0.4113 - val_accuracy: 0.8940 - val_loss: 0.3896 - learning_rate: 3.0000e-04
# Epoch 40/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8906 - loss: 0.3412 - val_accuracy: 0.8928 - val_loss: 0.3882 - learning_rate: 3.0000e-04
# Epoch 41/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 10s 54ms/step - accuracy: 0.8814 - loss: 0.4065 - val_accuracy: 0.8830 - val_loss: 0.4224 - learning_rate: 3.0000e-04
# Epoch 42/100
#   1/113 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.8672 - loss: 0.4210
# Epoch 42: ReduceLROnPlateau reducing learning rate to 9.000000427477062e-05.
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8672 - loss: 0.4210 - val_accuracy: 0.8815 - val_loss: 0.4302 - learning_rate: 3.0000e-04
# Epoch 43/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 10s 53ms/step - accuracy: 0.8845 - loss: 0.3972 - val_accuracy: 0.8799 - val_loss: 0.4008 - learning_rate: 9.0000e-05
# Epoch 44/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8750 - loss: 0.3822 - val_accuracy: 0.8811 - val_loss: 0.4013 - learning_rate: 9.0000e-05
# Epoch 45/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 9s 45ms/step - accuracy: 0.8949 - loss: 0.3792 - val_accuracy: 0.8928 - val_loss: 0.3742 - learning_rate: 9.0000e-05
# Epoch 46/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8906 - loss: 0.4181 - val_accuracy: 0.8924 - val_loss: 0.3749 - learning_rate: 9.0000e-05
# Epoch 47/100
# 112/113 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.8892 - loss: 0.3824
# Epoch 47: ReduceLROnPlateau reducing learning rate to 2.700000040931627e-05.
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 10s 46ms/step - accuracy: 0.8892 - loss: 0.3823 - val_accuracy: 0.8815 - val_loss: 0.3997 - learning_rate: 9.0000e-05
# Epoch 48/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8750 - loss: 0.3540 - val_accuracy: 0.8815 - val_loss: 0.3987 - learning_rate: 2.7000e-05
# Epoch 49/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 6s 54ms/step - accuracy: 0.8953 - loss: 0.3713 - val_accuracy: 0.8948 - val_loss: 0.3713 - learning_rate: 2.7000e-05
# Epoch 50/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8750 - loss: 0.3584 - val_accuracy: 0.8948 - val_loss: 0.3710 - learning_rate: 2.7000e-05
# Epoch 51/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 10s 51ms/step - accuracy: 0.8960 - loss: 0.3630 - val_accuracy: 0.8881 - val_loss: 0.3795 - learning_rate: 2.7000e-05
# Epoch 52/100
#   1/113 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - accuracy: 0.8672 - loss: 0.4075
# Epoch 52: ReduceLROnPlateau reducing learning rate to 8.100000013655517e-06.
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8672 - loss: 0.4075 - val_accuracy: 0.8881 - val_loss: 0.3799 - learning_rate: 2.7000e-05
# Epoch 52: early stopping
# Restoring model weights from the end of the best epoch: 37.
# Deep CNN v3 - Validation Accuracy: 0.8959 (89.59%)
# Best epoch: 37
#
# ============================================================
# ENSEMBLE SUMMARY
# ============================================================
# Model 1: Deep CNN - Validation Accuracy: 0.8807 (88.07%)
# Model 2: Wide CNN - Validation Accuracy: 0.8818 (88.18%)
# Model 3: ResNet-inspired - Validation Accuracy: 0.8756 (87.56%)
# Model 4: Compact Deep - Validation Accuracy: 0.8928 (89.28%)
# Model 5: Deep CNN v2 - Validation Accuracy: 0.8846 (88.46%)
# Model 6: Deep CNN v3 - Validation Accuracy: 0.8959 (89.59%)
#
# Average Individual Model Accuracy: 0.8852 (88.52%)
#
# ============================================================
# GENERATING ENSEMBLE PREDICTIONS
# ============================================================
# Generated predictions for Deep CNN (weight: 0.8807)
# Generated predictions for Wide CNN (weight: 0.8818)
# Generated predictions for ResNet-inspired (weight: 0.8756)
# Generated predictions for Compact Deep (weight: 0.8928)
# Generated predictions for Deep CNN v2 (weight: 0.8846)
# Generated predictions for Deep CNN v3 (weight: 0.8959)
#
# Ensemble submission file 'submission_ensemble_ultimate.csv' created successfully!
# Expected ensemble accuracy: 0.8952+ (89.52%+)
#
# Detailed predictions analysis saved to 'detailed_predictions_analysis.csv'
# This file shows individual model predictions vs ensemble prediction for each test sample.
